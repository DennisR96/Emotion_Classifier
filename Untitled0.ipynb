# %% [markdown]
# # Github

# %% [markdown]
# ## Initialize Repository

# %%
USERNAME = "DennisR96"                                      # DennisR96
EMAIL = "dennisraek@gmail.com"
TOKEN = "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"          # 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
REPOSITORY = "Colab_Test"                                   # Colab_Test

# !git clone https://$USERNAME:$TOKEN@github.com/$USERNAME/$REPOSITORY
# %cd $REPOSITORY
# !git config --global user.email $EMAIL
# !git config --global user.name $USERNAME
# Out:
# Cloning into 'Colab_Test'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 19 (delta 0), reused 13 (delta 0), pack-reused 0
# Receiving objects: 100% (19/19), done.
# /content/Colab_Test

# %% [markdown]
# ## Update Repository

# %%
# !gdown --output /content/$REPOSITORY/ 1X5Hu2uCxmke14oTdFyKRuOD_txy4ndO1
# !git add .
# !git commit -m "HALLO WELT123"
# !git push -u origin main
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X5Hu2uCxmke14oTdFyKRuOD_txy4ndO1
# To: /content/Colab_Test/Untitled0.ipynb
# 100% 2.73k/2.73k [00:00<00:00, 12.5MB/s]
# [main 4fb9eab] HALLO WELT123
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (89%)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/DennisR96/Colab_Test/'
