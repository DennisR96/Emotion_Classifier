# %% [markdown]
# # Github

# %% [markdown]
# ## Initialize Repository

# %%
USERNAME = input("INSERT USERNAME: ")             # DennisR96
TOKEN = input("INSERT TOKEN: ")                   # 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
REPOSITORY = input("INSERT REPOSITORY: ")         # Colab_Test

# !git clone https://$USERNAME:$TOKEN@github.com/$USERNAME/$REPOSITORY
# %cd $REPOSITORY
# Out:
# INSERT USERNAME: DennisR96
# INSERT TOKEN: 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
# INSERT REPOSITORY: Colab_Test
# Cloning into 'Colab_Test'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15 (delta 0), reused 9 (delta 0), pack-reused 0
# Receiving objects: 100% (15/15), done.
# /content/Colab_Test

# %%
# !git config --global user.email "dennisR96@gmail.com"
# !git config --global user.name "DennisR96"

# %% [markdown]
# ## Update Repository

# %%
# !gdown --output /content/$REPOSITORY/ 1X5Hu2uCxmke14oTdFyKRuOD_txy4ndO1
MESSAGE = input("INSERT COMMIT MESSAGE")

# !git add .
# !git commit -m "Hallo WEL"
# !git push -u origin main
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X5Hu2uCxmke14oTdFyKRuOD_txy4ndO1
# To: /content/Colab_Test/Untitled0.ipynb
# 100% 3.23k/3.23k [00:00<00:00, 14.5MB/s]
# INSERT COMMIT MESSAGEadded xy
# error: pathspec 'xy' did not match any file(s) known to git
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
